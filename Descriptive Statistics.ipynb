# %%
#Load Libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Load Data
df = pd.read_csv('./swiss.csv')
df.head()
# Out:
#    Fertility  Agriculture  Examination  Education  Catholic  InfantMortality
# 0       80.2         17.0           15         12      9.96             22.2
# 1       83.1         45.1            6          9     84.84             22.2
# 2       92.5         39.7            5          5     93.40             20.2
# 3       85.8         36.5           12          7     33.77             20.3
# 4       76.9         43.5           17         15      5.16             20.6

# %%
##Key Statistics (Numerical Columns only)
df.describe()
# Out:
#        Fertility  Agriculture  Examination  Education   Catholic  \
# count  47.000000    47.000000    47.000000  47.000000   47.00000
# mean   70.142553    50.659574    16.489362  10.978723   41.14383
# std    12.491697    22.711218     7.977883   9.615407   41.70485
# min    35.000000     1.200000     3.000000   1.000000    2.15000
# 25%    64.700000    35.900000    12.000000   6.000000    5.19500
# 50%    70.400000    54.100000    16.000000   8.000000   15.14000
# 75%    78.450000    67.650000    22.000000  12.000000   93.12500
# max    92.500000    89.700000    37.000000  53.000000  100.00000
#
#        InfantMortality
# count        47.000000
# mean         19.942553
# std           2.912697
# min          10.800000
# 25%          18.150000
# 50%          20.000000
# 75%          21.700000
# max          26.600000

# %%
##Standard Deviation Spread Graphs
def std_dev_plot(Variable_Name):
    
    #Spread
    data = df[Variable_Name]
    mean = df[Variable_Name].mean()
    std = df[Variable_Name].std()
    min_value = min(data)
    max_value = max(data)

    plt.hlines(y=mean - std, xmin=0, xmax=len(data), colors='r')
    plt.hlines(y=mean + std, xmin=0, xmax=len(data), colors='r')
    plt.hlines(y=mean - 2*std, xmin=0, xmax=len(data), colors='g')
    plt.hlines(y=mean + 2*std, xmin=0, xmax=len(data), colors='g')
    plt.hlines(y=mean - 3*std, xmin=0, xmax=len(data), colors='b')
    plt.hlines(y=mean + 3*std, xmin=0, xmax=len(data), colors='b')
   
    print('\nMeasure of Spread - STD')
    plt.title(Variable_Name)
    plt.scatter(x=df.index, y=df[Variable_Name])
    plt.hlines(y=mean, xmin=0, xmax=len(data))
    plt.show()
    
    #Central Tendacy
    print('Central Tendacy Statistics')
    print('\nMean: {:0.2f}'.format(df[Variable_Name].mean()))
    print('Median: {:0.2f}'.format(df[Variable_Name].median())) 
    print('Mode: {}'.format(df[Variable_Name].mode()))

# %%
#Create Output

std_dev_plot('Fertility')
std_dev_plot('Agriculture')
std_dev_plot('Education')
# Out:
# Measure of Spread - STD
# Central Tendacy Statistics
#
# Mean: 70.14
# Median: 70.40
# Mode: 0    65.0
# Name: Fertility, dtype: float64
#
# Measure of Spread - STD
# Central Tendacy Statistics
#
# Mean: 50.66
# Median: 54.10
# Mode: 0      1.2
# 1      7.7
# 2     15.2
# 3     16.7
# 4     17.0
# 5     17.6
# 6     18.7
# 7     19.4
# 8     26.8
# 9     27.7
# 10    34.0
# 11    35.3
# 12    36.5
# 13    37.6
# 14    38.4
# 15    39.7
# 16    43.5
# 17    45.1
# 18    45.2
# 19    46.6
# 20    49.5
# 21    50.9
# 22    53.3
# 23    54.1
# 24    55.1
# 25    58.1
# 26    59.8
# 27    60.7
# 28    60.8
# 29    62.0
# 30    63.1
# 31    63.5
# 32    64.5
# 33    64.9
# 34    67.5
# 35    67.8
# 36    69.3
# 37    70.2
# 38    71.2
# 39    72.6
# 40    73.0
# 41    75.9
# 42    78.2
# 43    84.6
# 44    84.9
# 45    85.9
# 46    89.7
# Name: Agriculture, dtype: float64
#
# Measure of Spread - STD
# Central Tendacy Statistics
#
# Mean: 10.98
# Median: 8.00
# Mode: 0    7
# Name: Education, dtype: int64

# %%
import seaborn as sns

data = df['Fertility']

# Create the histogram
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(data, kde=True)
plt.title('Fertility Histogram')
# Out:
# C:\Users\framz\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Fertility Histogram')

# %%
import seaborn as sns

data2 = df['Agriculture']

# Create the histogram
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(data2, kde=True)
plt.title('Agriculture Histogram')
# Out:
# C:\Users\framz\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Agriculture Histogram')

# %%
import seaborn as sns

data3 = df['Education']

# Create the histogram
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(data3, kde=True)
plt.title('Education Histogram')
# Out:
# C:\Users\framz\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Education Histogram')
